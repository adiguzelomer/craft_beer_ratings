# %% [markdown]
# # EDA with our first model

# %%
import pickle
import pandas as pd
import numpy as np
import src.nlp as nlp
from pprint import pprint
import matplotlib.pyplot as plt

# %%
def unpickle(filename: str):
    """Returns the unpickled object from the file.
    """
    with open(filename, 'rb') as p:
        item = pickle.load(p)
    return item

# %%
beer_df, reviews_df = nlp.load_data('data/beers.csv', 'data/reviews.csv')

reviews_df['text'] = [nlp.remove_bad_text(text) for text in reviews_df['text'].values]

# %%
W = unpickle('pickles/W.pkl')
NMF = unpickle('pickles/NMF.pkl')
TFIDF_Vectorizer = unpickle('pickles/TF-IDF-Vectorizer.pkl')
TFIDF = unpickle('pickles/TF-IDF.pkl')

# %% [markdown]
# ## Find the keywords associated with each topic

# %% [markdown]
# Let's find the top 10 words associated with our top ten topics.

# %%
topic_vectors = NMF.components_
feature_names = TFIDF_Vectorizer.get_feature_names()

# %%
def get_top_15_topics_words(topic_vectors, feature_names):
    top_words = []
    for idx in range(15):
        top_words.append(get_top_words(topic_vectors[idx], feature_names))
    return top_words
    
def get_top_words(topic_vector, feature_names):
    top_words_idxs = np.argsort(topic_vector)[-1:-16:-1]
    top_words = [feature_names[idx] for idx in top_words_idxs]
    return top_words

# %%
top_15 = get_top_15_topics_words(topic_vectors, feature_names)

# %%
for topic in top_15:
    print(topic)
# Out:
# ['hop', 'malt', 'bit', 'caramel', 'bal', 'flav', 'fin', 'amb', 'arom', 'sweet', 'flor', 'slight', 'earthy', 'dry', 'wel']
# ['coff', 'chocol', 'roast', 'black', 'stout', 'dark', 'port', 'malt', 'creamy', 'tan', 'brown', 'roasty', 'bit', 'flav', 'coco']
# ['on', 'lik', 'real', 'get', 'ev', 'brew', 'would', 'much', 'tim', 'try', 'first', 'look', 'think', 'way', 'com']
# ['dark', 'brown', 'fruit', 'caramel', 'sug', 'sweet', 'alcohol', 'raisin', 'toff', 'malt', 'plum', 'rich', 'warm', 'fig', 'red']
# ['sour', 'tart', 'cherry', 'funk', 'acid', 'red', 'oak', 'vineg', 'appl', 'raspberry', 'funky', 'dry', 'win', 'grap', 'fruit']
# ['citr', 'orang', 'grapefruit', 'pin', 'ip', 'trop', 'pineappl', 'mango', 'fruit', 'whit', 'bit', 'hazy', 'juicy', 'hop', 'resin']
# ['yeast', 'banan', 'clov', 'whe', 'belg', 'spic', 'spicy', 'whit', 'fru', 'gold', 'cloudy', 'yeasty', 'hazy', 'lemon', 'appl']
# ['bourbon', 'vanill', 'oak', 'barrel', 'ag', 'boozy', 'not', 'coconut', 'mapl', 'toff', 'chocol', 'whiskey', 'caramel', 'booz', 'black']
# ['nic', 'real', 'bal', 'wel', 'gre', 'mal', 'brew', 'col', 'drink', 'smoo', 'lac', 'pour', 'head', 'creamy', 'easy']
# ['pumpkin', 'spic', 'cinnamon', 'nutmeg', 'pie', 'al', 'orang', 'ging', 'allsp', 'clov', 'fal', 'season', 'flav', 'spicy', 'wint']
# ['littl', 'smel', 'tast', 'bit', 'sweet', 'lik', 'slight', 'mouthfeel', 'drink', 'overal', 'appear', 'mal', 'head', 'much', 'alcohol']
# ['beer', 'gre', 'tast', 'drink', 'flav', 'smel', 'col', 'perfect', 'easy', 'mak', 'lov', 'arom', 'enjoy', 'favorit', 'best']
# ['light', 'crisp', 'lag', 'body', 'grain', 'whit', 'cle', 'carbon', 'clear', 'gold', 'mod', 'refresh', 'med', 'fin', 'pal']
# ['bottl', 'glass', 'pour', 'pint', 'oz', '12', 'lac', 'tulip', 'leav', 'serv', 'dat', '12oz', 'fing', 'head', '11']
# ['good', 'pretty', 'amount', 'ret', 'lac', 'overal', 'carbon', 'styl', 'drink', 'tast', 'head', 'dec', 'solid', 'mouthfeel', 'col']

# %% [markdown]
# ## Find the top 10 reviews associated with each topic

# %%
top_reviews_idx = np.argsort(W[:, 0])[-1:-11:-1]

# %%
reviews_df.iloc[top_reviews_idx]
# Out:
#                                            author                        beer  \
# 26558   /community/members/michaelcbyrnes.738649/  smuttynose shoals pale ale
# 311963  /community/members/paco1029384756.203924/                   nosferatu
# 209708        /community/members/okbrew89.732424/              marble red ale
# 349649             /community/members/winter.906/       fuller's london pride
# 571079          /community/members/ttroha.706624/          double bastard ale
# 634358          /community/members/samp01.479260/                dead guy ale
# 215100        /community/members/ngeunit1.348087/     homegrown fresh hop ale
# 123225           /community/members/zacht.750791/        hermann's dark lager
# 52221    /community/members/stephenjmoore.568544/             james black ale
# 500920        /community/members/ngeunit1.348087/  smuttynose shoals pale ale
#
#         feel  look  overall  \
# 26558   4.75  4.50     4.75
# 311963  4.50  4.50     4.00
# 209708  3.75  4.25     4.00
# 349649  3.50  4.00     4.00
# 571079   NaN   NaN      NaN
# 634358  3.50  4.00     4.00
# 215100  4.00  4.00     4.00
# 123225  4.50  3.50     3.75
# 52221   4.25  4.50     4.50
# 500920  4.00  4.00     4.00
#
#                                                 review_id  smell  taste  \
# 26558   smuttynose brewing company smuttynose shoals p...   4.75   4.75
# 311963              great lakes brewing co. nosferatu 632   4.00   4.00
# 209708                   marble brewery marble red ale 14   4.00   4.00
# 349649  fuller smith & turner plc fuller's london prid...   4.00   4.00
# 571079          arrogant consortia double bastard ale 142    NaN    NaN
# 634358                        rogue ales dead guy ale 796   3.50   4.00
# 215100  moonlight brewing company homegrown fresh hop ...   4.50   4.50
# 123225    vancouver island brewing hermann's dark lager 2   3.50   3.75
# 52221           hill farmstead brewery james black ale 28   4.75   4.50
# 500920  smuttynose brewing company smuttynose shoals p...   4.00   4.50
#
#                                                      text  \
# 26558   A: copper, golden red with foamy white head a ...
# 311963  Pours a deep ruby color with a very small, smo...
# 209708  Poured into a pint glass. Reddish amber color ...
# 349649  Poured a clear amber in color with an off-whit...
# 571079  Tap from Maltitude. Pours cloudy amber with wh...
# 634358  Pours a cloudy copper with a nice creamy off w...
# 215100  A - Served a clear copper-amber color with a f...
# 123225  A: Ruby brown color, clear, about a finger of ...
# 52221   A- Very dark brown body with a bubbly tan head...
# 500920  A - Pours a bright slightly haze copper-orange...
#
#                                                 brew_beer  review_num
# 26558   smuttynose brewing company smuttynose shoals p...          39
# 311963                  great lakes brewing co. nosferatu         632
# 209708                      marble brewery marble red ale          14
# 349649    fuller smith & turner plc fuller's london pride        1065
# 571079              arrogant consortia double bastard ale         142
# 634358                            rogue ales dead guy ale         796
# 215100  moonlight brewing company homegrown fresh hop ale           5
# 123225      vancouver island brewing hermann's dark lager           2
# 52221              hill farmstead brewery james black ale          28
# 500920  smuttynose brewing company smuttynose shoals p...         167

# %%
def get_all_topics_top_ten(W, reviews_df):
    topics = []
    for idx in range(W.shape[1]):
        topics.append(get_top_ten_reviews(W, idx, reviews_df))
    return topics

def get_top_ten_reviews(W, topic_idx, reviews_df):
    top_reviews_idx = np.argsort(W[:, topic_idx])[-1:-11:-1]
    return reviews_df.iloc[top_reviews_idx]

# %%
top_ten_reviews_by_topic = get_all_topics_top_ten(W, reviews_df)

# %%
for topic in top_ten_reviews_by_topic:
    print(topic[['beer', 'overall']])
    print()
# Out:
#                               beer  overall
# 26558   smuttynose shoals pale ale     4.75
# 311963                   nosferatu     4.00
# 209708              marble red ale     4.00
# 349649       fuller's london pride     4.00
# 571079          double bastard ale      NaN
# 634358                dead guy ale     4.00
# 215100     homegrown fresh hop ale     4.00
# 123225        hermann's dark lager     3.75
# 52221              james black ale     4.50
# 500920  smuttynose shoals pale ale     4.00
#
#                            beer  overall
# 184486                  unjunct     4.00
# 478856                    stout     4.00
# 648988      beer geek breakfast     4.00
# 673801     coffee oatmeal stout     4.00
# 698545  bean me up coffee stout     4.25
# 603138     cafe con leche stout     4.00
# 496191                     bdcs     4.25
# 614073               kaffestout     4.50
# 560972             mocha marlin     4.00
# 692378      beer geek breakfast     4.00
#
#                                               beer  overall
# 533645                                   the abyss      5.0
# 638792                  thumbprint imperial weizen      5.0
# 758470     the angel's share - bourbon barrel-aged      4.5
# 287874                     wee heavy - barrel-aged      5.0
# 548813          thomas hooker liberator doppelbock      4.5
# 170422                               beatification      5.0
# 740144                           raspberry eisbock      4.0
# 372373          sublimely self-righteous black ipa      5.0
# 34402                   louie's reserve scotch ale      4.5
# 214040  abbaye des rocs [brasserie des rocs brune]      4.0
#
#                                   beer  overall
# 164043                    gulden draak     3.50
# 37146                     gulden draak     4.00
# 224189        scotty karate scotch ale     4.00
# 84831          trappistes rochefort 10     3.75
# 352763  allgäuer cambonator doppelbock     4.50
# 381270                          §ucaba     4.50
# 623404                  première (red)     4.00
# 322137                robert the bruce     4.00
# 720839          trappistes rochefort 8     4.50
# 21953                     way amburana     4.00
#
#                                   beer  overall
# 657293  wild sour series: flanders red     3.25
# 506546                    supplication     4.00
# 187036  oud beersel oude kriek vieille     4.00
# 706437        cuvée des jacobins rouge     4.50
# 227687             oude lambiek de cam     4.00
# 81051      cantillon rosé de gambrinus     3.50
# 45698                       oude kriek      NaN
# 137187                        la folie     4.50
# 154004                    supplication     4.75
# 458478    monk's café flemish sour ale     4.25
#
#                                     beer  overall
# 113081                              haze     4.50
# 129190                   pliny the elder     4.25
# 562501                      xhops - gold     4.25
# 616855                       zombie dust     4.50
# 419003  winter ale (5th anniversary ale)     4.50
# 62144                       jai alai ipa     4.25
# 219927                             sosus     4.50
# 711411                  todd the axe man     4.50
# 245949                               ipa     3.75
# 772966                    hoppy birthday     4.00
#
#                                               beer  overall
# 623377                                 don de dieu     4.00
# 80995                        weihenstephaner vitus     4.25
# 176057  weihenstephaner / sierra nevada - braupakt     4.25
# 504925       schneider weisse tap 7 unser original     4.00
# 22007            paulaner hefe-weissbier naturtrüb     4.00
# 391156  weihenstephaner / sierra nevada - braupakt     4.75
# 512593                    final absolution trippel     3.00
# 271525                                  kellerweis     4.00
# 22147                weihenstephaner hefeweissbier     4.50
# 340159                   westmalle trappist tripel     5.00
#
#                                                 beer  overall
# 3693      brewer's reserve bourbon barrel barleywine     2.75
# 446474                 people's porter - barrel-aged     2.50
# 589301         dark apparition - bourbon barrel-aged     4.25
# 662591    big sound scotch ale - bourbon barrel aged     4.25
# 288071  bourbon barrel hellfighter (w/ vanilla bean)     4.25
# 42383            bourbon county brand barleywine ale     4.50
# 261573  bourbon barrel hellfighter (w/ vanilla bean)     4.25
# 132929              black jack (bourbon barrel aged)     4.00
# 80032                    bourbon barrel porter (bbp)     3.00
# 525952                          louie's resurrection     3.75
#
#                                                  beer  overall
# 224115                                 union jack ipa     4.50
# 438395                                  pisgah valdez     4.50
# 99828                  cbs (canadian breakfast stout)     5.00
# 476972                                  schell's bock     4.00
# 421864                     dawn of the red i.r.a. ale     4.25
# 339956                                   mocha marlin     4.25
# 241625                   magnumus ete tomahawkus esb³     4.00
# 327821                          ipswich oatmeal stout     4.50
# 739990                                        glaucus     4.25
# 317205  bourbon barrel aged dark star: coffee edition     4.50
#
#                                     beer  overall
# 57352                         punkin ale     4.00
# 511396                        punkin ale     3.50
# 26000              night owl pumpkin ale     3.75
# 94976              night owl pumpkin ale     4.25
# 607364  frog's hollow double pumpkin ale     3.50
# 202334                        punkin ale     4.00
# 344101                        punkin ale     4.00
# 45478                         punkin ale     3.75
# 707893     rogue farms pumpkin patch ale     4.00
# 676210              imperial pumpkin ale     4.00
#
#                                           beer  overall
# 662069                             honey weiss      3.5
# 15629          cali creamin' vanilla cream ale      4.0
# 516034                  warka premium (strong)      3.0
# 661404                              celebrator      5.0
# 481285                          old horizontal      3.0
# 726024                           spaten dunkel      4.0
# 558241            lucky 13 mondo large red ale      3.5
# 11258                               immort ale      3.5
# 52606                           ur-bock dunkel      4.0
# 486722  undercover investigation shut-down ale      3.5
#
#                                       beer  overall
# 66387              odell easy street wheat     3.50
# 14639                                 1554     4.00
# 417495                        hudy delight     3.00
# 75137                    backwoods bastard     3.75
# 649064  girardin gueuze 1882 (black label)     4.50
# 386512            cantillon saint lamvinus     5.00
# 382162               wisconsin belgian red     4.50
# 498173       old chub - scottish style ale     4.50
# 525306                       old stock ale     5.00
# 41459     steel reserve 211 (high gravity)     3.00
#
#                                   beer  overall
# 55634                       solid gold     3.75
# 403285               reclamation lager     3.75
# 344449                 sam adams light     3.00
# 587961         pabst blue ribbon (pbr)     3.00
# 325091  pure brewed organic lager beer     3.50
# 55909                       harp lager     5.00
# 274029                 asahi super dry     3.00
# 221731                   opa opa light     3.50
# 319884               naked river light     4.00
# 327101             estrella damm daura     2.50
#
#                                                     beer  overall
# 183873                               moonglow weizenbock     4.25
# 173412                                  estrella galicia     3.00
# 87408                                pataskala red x ipa     3.50
# 61559   hacker-pschorr original oktoberfest amber märzen     4.50
# 483508                          hunahpu's imperial stout     4.50
# 165594       my antonia (birra del borgo & dogfish head)     4.50
# 693070                                      winter storm     4.50
# 147459                                   preseason lager     4.25
# 415963                                         rebellion     3.75
# 382003                          revolver blood and honey     4.25
#
#                              beer  overall
# 739469                white rajah     3.25
# 562103                  pranqster     4.50
# 633650                     oscura     4.00
# 477363            two hearted ale     4.00
# 691667          hopback amber ale     4.50
# 401181              coffee bender     4.00
# 779286                      lager     4.00
# 429229  samuel adams boston lager     3.50
# 254113              red oak amber     4.50
# 615246    pabst blue ribbon (pbr)     4.00

# %% [markdown]
# ## Hierarchical Clustering
# Here I'll take the mean review vector for each beer and cluster the beers.
#
# The first step is to calculate the topic vector for each beer. To do this we will produce a topic vector for the beer based on a TF-IDF vector for text comprising all the reviews associated with that beer.

# %%
beer_df, reviews_df = nlp.load_data('data/beers.csv', 'data/reviews.csv', 500)

# %%
two_hearted = beer_df[beer_df['beer'] == 'two hearted ale']['review_id'].iloc[0]

# %%
two_hearted_reviews = reviews_df[reviews_df['brew_beer']==two_hearted]
two_hearted_reviews.head(2)
# Out:
#                                 author             beer  feel  look  overall  \
# 315    /community/members/kendo.56471/  two hearted ale   4.5   4.5      5.0
# 412  /community/members/elmocoso.1146/  two hearted ale   5.0   4.5      5.0
#
#                                              review_id  smell  taste  \
# 315  bell's brewery - eccentric café & general stor...    4.5    4.5
# 412  bell's brewery - eccentric café & general stor...    4.5    4.5
#
#                                                   text  \
# 315  4.6/5  rDev +7.7%look: 4.5 | smell: 4.5 | tast...
# 412  4.65/5  rDev +8.9%look: 4.5 | smell: 4.5 | tas...
#
#                                              brew_beer  review_num
# 315  bell's brewery - eccentric café & general stor...        2213
# 412  bell's brewery - eccentric café & general stor...        3600

# %%
two_hearted_texts = two_hearted_reviews['text'].values
two_hearted_texts = nlp.clean_documents(two_hearted_texts)

# %%
two_hearted_text = ' '.join(list(two_hearted_texts))

# %%
two_hearted_tfidf = TFIDF_Vectorizer.transform([two_hearted_text])

# %%
two_hearted_tfidf.toarray().shape
# Out:
# (1, 5000)

# %%
NMF.components_.shape
# Out:
# (15, 5000)

# %%
vector = two_hearted_tfidf.dot(NMF.components_.T)

# %%
vector.shape
# Out:
# (1, 15)

# %%
vector
# Out:
# array([[6.92170801, 1.53932432, 4.67612745, 2.31016219, 1.51395133,
#         6.07888996, 2.52513984, 0.79055697, 2.41459247, 0.51903357,
#         3.73769884, 3.74689513, 2.80610606, 2.2497328 , 1.84723804]])

# %%
def get_beer_mega_review(brew_beer: str, reviews_df: pd.DataFrame):
    """Return a string of the reviews associated with the given beer.
    """
    reviews = reviews_df[reviews_df['brew_beer']==brew_beer]
    texts = reviews['text'].values
    texts = nlp.clean_documents(texts)
    return ' '.join(list(texts))

def get_all_beer_tf_idf(brew_beers: list, reviews_df: pd.DataFrame, tfidf_vectorizer):
    """Return the tf_idf matrix for all the beers listed.
    """
    
    reviews = [get_beer_mega_review(brew_beer, reviews_df) for brew_beer in brew_beers]
    return tfidf_vectorizer.transform(reviews)

# %%
brew_beers = beer_df['review_id']

# %%
tf_idf = get_all_beer_tf_idf(brew_beers, reviews_df, TFIDF_Vectorizer)

# %%
from scipy.spatial.distance import pdist, squareform
from scipy.cluster.hierarchy import linkage, dendrogram

# %%
distxy = squareform(pdist(tf_idf.todense(), metric='cosine'))

# %%
link = linkage(distxy, method='complete')
# Out:
# /Users/brettcastellanos/miniconda3/envs/craft-beer/lib/python3.7/site-packages/ipykernel_launcher.py:1: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   """Entry point for launching an IPython kernel.

# %%
labels = beer_df['beer'].values + ' | ' + beer_df['style']

fig =plt.figure(figsize=(60,20))
dendro = dendrogram(
    link, color_threshold=1.5, leaf_font_size=9,
    labels=labels.values, # orientation='right'
)
plt.subplots_adjust(top=.99, bottom=0.5, left=0.05, right=0.99)
plt.savefig('figure1')
plt.show()
# Out:
# /Users/brettcastellanos/miniconda3/envs/craft-beer/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 158 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/brettcastellanos/miniconda3/envs/craft-beer/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 158 missing from current font.
#   font.set_text(s, 0, flags=flags)
